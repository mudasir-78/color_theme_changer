# %% [markdown]
# <a href="https://colab.research.google.com/github/mudasir-78/color_theme_changer/blob/main/DIP_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Google Drive mount karo yani iss k sth joro
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Required libraries import karo yhn pr jo jo libarires project k lie zarorat hn wo import krni hn
import os
import cv2
import numpy as np

# Step 3: Folder paths define karo yhn pr jiss jigha folder hn whn ka path dina hy

clean_path = '/content/drive/MyDrive/Clean water'      # Clean water folder ka path hy jhn pr folder ho ga
polluted_path = '/content/drive/MyDrive/Polluted water' # Polluted water folder ka path ye dosary folder ka path hy

# Step 4: Images aur labels store karne ke liye lists x aor y varibales hn store krny k lie images ko aor lables krny k lie
X = []
y = []

# Step 5: Clean water images load karo yhn pr clean water images ko load krny ka code hy

for img_name in os.listdir(clean_path):
    img_path = os.path.join(clean_path, img_name)
    img = cv2.imread(img_path)              # Image read karo
    img = cv2.resize(img, (224, 224))      # Resize karo (CNN ke liye)
    X.append(img)
    y.append(0)                             # Clean water = 0

# Step 6: Polluted water images load karo yhn pr water images ko load krny ka code hy

for img_name in os.listdir(polluted_path):
    img_path = os.path.join(polluted_path, img_name)
    img = cv2.imread(img_path)
    img = cv2.resize(img, (224, 224))
    X.append(img)
    y.append(1)                             # Polluted water = 1

# Step 7: Lists ko numpy arrays me convert karo yhn pr jo list bani hy array mn convert krni hy ye code hy
X = np.array(X)
y = np.array(y)

# Step 8: Check shapes
print("Images shape:", X.shape)
print("Labels shape:", y.shape)

# Step 9: Normalize images (0-1 range)
X = X / 255.0

print("Data ready for CNN!")
print("Images shapes;", X.shape )
print("Lables shapes;", y.shape )
# Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(X_train, y_train, epochs=5)

# Test
model.evaluate(X_test, y_test)
# Out:
# Mounted at /content/drive
# Images shape: (120, 224, 224, 3)
# Labels shape: (120,)
# Data ready for CNN!
# Images shapes; (120, 224, 224, 3)
# Lables shapes; (120,)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 966ms/step - accuracy: 0.4401 - loss: 7.7078
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5208 - loss: 7.4158
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 958ms/step - accuracy: 0.4284 - loss: 7.4793
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 948ms/step - accuracy: 0.6263 - loss: 5.9810
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.6380 - loss: 3.6484
# ...
